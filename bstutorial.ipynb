# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.newegg.ca/lenovo-intel-core-i5-1135g-intel-iris-xe-graphics-16gb-memory-512-gb-ssd-black/p/1XV-0001-02T23"

# %%
result = requests.get(url)

# %%
site = BeautifulSoup(result.text, "html.parser")
print(site.prettify())
# Out:
# <!DOCTYPE html>
# <html class="show-tab-store is-new" lang="en-ca">
#  <head>
#   <title>
#    Refurbished: Lenovo ThinkPad E15 Gen 2 Intel Core i5 1135G7 16GB RAM 512GB SSD 15.6" FHD Iris Xe Graphics - Windows 11 Pro - Newegg.ca
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="always" name="referrer"/>
#   <meta content='Newegg, Newegg.ca, Refurbished: Lenovo ThinkPad E15 Gen 2 Intel Core i5 1135G7 16GB RAM 512GB SSD 15.6" FHD Iris Xe Graphics - Windows 11 Pro' name="keywords"/>
#   <meta content='Buy Refurbished: Lenovo ThinkPad E15 Gen 2 Intel Core i5 1135G7 16GB RAM 512GB SSD 15.6" FHD Iris Xe Graphics - Windows 11 Pro with fast shipping and top-rated customer service. Newegg shopping upgraded ™' name="description"/>
#   <meta content="https://c1.neweggimages.com/ProductImage/BX64S25071013JP4J33.jpg" property="og:image"/>
# ...

# %%
prices = site.find_all(text = "$")
print(prices)
price = prices[0].parent
# Out:
# ['$']
# C:\Users\Yusha S\AppData\Local\Temp\ipykernel_6840\788126610.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   prices = site.find_all(text = "$")

# %%
strong = price.find('strong')
print(strong.string)
# Out:
# 549

# %% [markdown]
# Or use the following method to get the price

# %%
print(price.get_text())
# Out:
# $549.00

# %%
with open("index.html", 'r') as file:
    doc = BeautifulSoup(file, "html.parser")

# %%
print(doc.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Your Title Here
#   </title>
#  </head>
#  <body bgcolor="FFFFFF">
#   <center>
#    <img align="BOTTOM" src="clouds.jpg"/>
#   </center>
#   <hr/>
#   <a href="http://somegreatsite.com">
#    Link Name
#   </a>
#   is a link to another nifty site
#   <h1>
#    This is a Header
#   </h1>
#   <h2>
#    This is a Medium Header
#   </h2>
#   Send me mail at
#   <a href="mailto:support@yourcompany.com">
#    support@yourcompany.com
#   </a>
#   .
#   <p>
#    This is a new paragraph!
#    <p>
#     <b color="red">
#      This is a new paragraph!
#     </b>
#     <br/>
#     <b>
#      <i>
#       This is a new sentence without a paragraph break, in bold italics.
#      </i>
#     </b>
#     <hr/>
#    </p>
#   </p>
#  </body>
# </html>

# %%
tag = doc.title
tag.string = 'Hello'
print(tag.string)
# Out:
# Hello

# %%
tags = doc.find_all("p")
print(tags)
# Out:
# [<p> This is a new paragraph!
#
# <p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# <hr/>
# </p></p>, <p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# <hr/>
# </p>]

# %%
for tag in tags:
    print(tag.get_text())
# Out:
#  This is a new paragraph!
#
#  This is a new paragraph!
#  This is a new sentence without a paragraph break, in bold italics.
#
#
#  This is a new paragraph!
#  This is a new sentence without a paragraph break, in bold italics.
